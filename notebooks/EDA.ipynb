# %%
import pandas as pd

df = pd.read_csv("../data/churn.csv")

print(df.head())

print(df.info())

print(df.describe())

print(df.isnull().sum())

print(df.duplicated().sum())
# Out:
#    CustomerID  Gender  Age  Tenure  MonthlyCharges  TotalCharges  \
# 0        1001    Male   25       2            45.5          91.0
# 1        1002  Female   32      24            70.2        1684.8
# 2        1003    Male   45      36            85.6        3081.6
# 3        1004  Female   29       5            55.4         277.0
# 4        1005    Male   38      18            65.8        1184.4
#
#      ContractType InternetService     PaymentMethod  Churn
# 0  Month-to-month     Fiber optic       Credit Card      1
# 1        One year             DSL     Bank Transfer      0
# 2        Two year     Fiber optic       Credit Card      0
# 3  Month-to-month             DSL  Electronic Check      1
# 4        One year     Fiber optic       Credit Card      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       30 non-null     int64
#  1   Gender           30 non-null     object
#  2   Age              30 non-null     int64
#  3   Tenure           30 non-null     int64
#  4   MonthlyCharges   30 non-null     float64
#  5   TotalCharges     30 non-null     float64
#  6   ContractType     30 non-null     object
#  7   InternetService  30 non-null     object
#  8   PaymentMethod    30 non-null     object
#  9   Churn            30 non-null     int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 2.5+ KB
# None
#         CustomerID        Age     Tenure  MonthlyCharges  TotalCharges  \
# count    30.000000  30.000000  30.000000       30.000000     30.000000
# mean   1015.500000  35.166667  22.966667       68.116667   1885.306667
# std       8.803408   8.971539  18.925413       17.977746   1836.385080
# min    1001.000000  21.000000   1.000000       39.900000     39.900000
# 25%    1008.250000  28.250000   6.250000       53.900000    326.450000
# 50%    1015.500000  34.500000  19.000000       67.500000   1273.200000
# 75%    1022.750000  42.500000  37.500000       85.325000   3178.650000
# max    1030.000000  52.000000  60.000000       98.400000   5904.000000
#
#            Churn
# count  30.000000
# mean    0.366667
# std     0.490133
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     1.000000
# max     1.000000
# CustomerID         0
# Gender             0
# Age                0
# Tenure             0
# MonthlyCharges     0
# TotalCharges       0
# ContractType       0
# InternetService    0
# PaymentMethod      0
# Churn              0
# dtype: int64
# 0

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(10,8))

plt.show()

# %%
import seaborn as sns

sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
